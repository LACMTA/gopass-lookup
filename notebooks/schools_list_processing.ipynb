# %% [markdown]
# # Jupyter Notebook for converting the Go Pass Data

# %% [markdown]
# ## 1.0 Load in modules
#
# We are using pandas and the numpy libraries to read and process the data.
#
# Then we will use the `rapidfuzz` library to caclulate close matches to the strings so that we can join the information.
#
# Using other popular fuzzy-string matching libraries like `fuzzball` takes over 3 hours to process as the alogrithim used takes the number of records to the `n`th power!! (i.e. comparing 1000 records processes 1000^1000!!!) `rapidfuzz` has a better algorithm that trims this town to 3 - 4 minutes!

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from rapidfuzz import process, utils as fuzz_utils

GOOGLE_SHEET_URL = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSWbwrsqF-c---4lfw0LZWymd-f8sy8sLYkXgzh0OyeGATWwrvv7V1Mq5BcApn7F_-WYKP1KXy5shKw/pub?output=csv'

# %% [markdown]
# ## 2.0 Format Go Pass Data
#
# We will be extracting the following fields:
#
# - District
# - School
# - Address
# - City
# - Participating
#
# We create a simplfied field called `name` based on the `street address`, `school name`, and `district`. This field is formatted to be all lowercase with spaces replaced with `-` to make matching easier.

# %%
go_pass_schools = pd.read_csv(GOOGLE_SHEET_URL,
    usecols={'District','School','Address','City','Telephone','Participating'})
go_pass_schools.columns = ["district","name","address","city",'telephone',"participating"]

go_pass_schools = go_pass_schools.fillna('')
go_pass_schools['original_name'] = go_pass_schools['name']
simple_district = go_pass_schools['district'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
# go_pass_schools['name'] = go_pass_schools['name'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')+"-"+simple_district
simple_address = go_pass_schools['address'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
go_pass_schools.loc[(go_pass_schools['name'].str.len() > 1),'name'] = simple_address+"-"+go_pass_schools['name'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')+"-"+simple_district
go_pass_schools
# Out:
# <ipython-input-2-5948509e4fd8>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   simple_district = go_pass_schools['district'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
# <ipython-input-2-5948509e4fd8>:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   simple_address = go_pass_schools['address'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
# <ipython-input-2-5948509e4fd8>:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   go_pass_schools.loc[(go_pass_schools['name'].str.len() > 1),'name'] = simple_address+"-"+go_pass_schools['name'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')+"-"+simple_district
#                  district                                               name  \
# 0        Centinela Valley  4859-west-el-segundo-blvd-hawthorne-high-centi...
# 1        Centinela Valley  14901-s-inglewood-avenue-lawndale-high-centine...
# 2        Centinela Valley  4118-west-rosecrans-ave-leuzinger-high-centine...
# 3        Centinela Valley   4951-marine-ave-r-k-lloyde-high-centinela-valley
# 4                 Charter  461-9th-street,-san-pedro-alliance-alice-m-bax...
# ...                   ...                                                ...
# 1477              Private    1253-bishops-road-cathedral-high-school-private
# 1478              Private  6361-santa-monica-blvd-episcopal-school-of-los...
# 1479              Private          9650-zelzah-ave-northpoint-school-private
# 1480  Santa Monica-Malibu
# 1481        Whittier UHSD
#
#                          address         city       telephone  participating  \
# 0     4859 West El Segundo Blvd.    Hawthorne  (310) 263-4400           True
# 1      14901 S. Inglewood Avenue     Lawndale  (310) 263-3100           True
# 2       4118 West Rosecrans Ave.     Lawndale  (310) 263-2200           True
# 3               4951 Marine Ave.     Lawndale  (310) 263-3264           True
# 4      461 9th Street, San Pedro    San Pedro  (310) 221-0430           True
# ...                          ...          ...             ...            ...
# 1477           1253 Bishops Road  Los Angeles  (323) 441-3113           True
# 1478     6361 Santa Monica Blvd.  Los Angeles  (323) 284-7266           True
# 1479            9650 Zelzah Ave.   Northridge  (818) 739-5231           True
# 1480                                                                    True
# 1481                                                                    True
#
#                                           original_name
# 0                                        Hawthorne High
# 1                                         Lawndale High
# 2                                        Leuzinger High
# 3                                     R. K. Lloyde High
# 4     Alliance Alice M. Baxter College-Ready High Sc...
# ...                                                 ...
# 1477                              Cathedral High School
# 1478                    Episcopal School of Los Angeles
# 1479                                  Northpoint School
# 1480
# 1481
#
# [1482 rows x 7 columns]

# %% [markdown]
# ### 2.1 Format California Schools data
#
# We create a simplfied field called `simple name` based on the `street address`, `school name`, and `district`. This field is formatted to be all lowercase with spaces replaced with `-` to make matching easier.
#
# #### Source for California schools data
#
# https://www.cde.ca.gov/SchoolDirectory/ExportSelect?simpleSearch=N&address=&city=&counties=&districts=&cdscode=&charter=&magnet=&name=&nps=&search=2&zip=&yearround=&status=1%2C2&types=&order=1&multilingual=&qsc=3549&qdc=3549
#
# August 2022

# %%
california_schools_data = "../data/CDESchoolDirectoryExportAugust2022.csv"

california_schools = pd.read_csv(california_schools_data,
    usecols={'County','Status','District','School',"Closed Date","Website","Latitude","Longitude","Last Update",'Street Address','Street City',"Phone","Email"},encoding='latin')
california_schools.columns = ["county","district","name","status","closed_date","website","latitude","longitude","last_update","address","city","default_phone","email"]

california_schools = california_schools.fillna('')
la_schools_df = california_schools[california_schools["county"] == "Los Angeles"]

la_schools_df['original_name'] = la_schools_df['name']

la_schools_df.loc[la_schools_df['district'] == "Los Angeles Unified", 'district'] = "LAUSD"
simple_district = la_schools_df['district'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
simple_address = la_schools_df['address'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')

la_schools_df['simple_name'] = simple_address+"-"+la_schools_df['name'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')+"-"+simple_district


la_schools_df
# Out:
# <ipython-input-3-d9bd7dbee630>:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   simple_district = la_schools_df['district'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
# <ipython-input-3-d9bd7dbee630>:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   simple_address = la_schools_df['address'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
# <ipython-input-3-d9bd7dbee630>:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   la_schools_df['simple_name'] = simple_address+"-"+la_schools_df['name'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')+"-"+simple_district
#            county          district  \
# 0     Los Angeles       ABC Unified
# 1     Los Angeles       ABC Unified
# 2     Los Angeles       ABC Unified
# 3     Los Angeles       ABC Unified
# 4     Los Angeles       ABC Unified
# ...           ...               ...
# 5824  Los Angeles  Wiseburn Unified
# 5825  Los Angeles  Wiseburn Unified
# 5826  Los Angeles  Wiseburn Unified
# 5827  Los Angeles  Wiseburn Unified
# 5828  Los Angeles  Wiseburn Unified
#
#                                               name  status closed_date  \
# 0                                        ABC Adult  Active     No Data
# 1                          ABC Evening High School  Closed  11/23/1994
# 2                      ABC Secondary (Alternative)  Active     No Data
# 3                    Accelerated Christian Academy  Closed   5/12/2016
# 4                                 Aloha Elementary  Active     No Data
# ...                                            ...     ...         ...
# 5824                       Juan De Anza Elementary  Active     No Data
# 5825  Malaga Cove School - Success Learning Center  Closed   6/30/2016
# 5826                     Richard Henry Dana Middle  Active     No Data
# 5827                                     RISE High  Closed    9/1/2018
# 5828                       Success Learning Center  Active     No Data
#
#                         website              latitude             longitude  \
# 0     http://abcadultschool.edu             33.878924           -118.071286
# 1                       No Data               No Data               No Data
# 2                       No Data             33.881547           -118.046358
# 3                       No Data  Information Redacted  Information Redacted
# 4                www.alohaes.us             33.835176           -118.083725
# ...                         ...                   ...                   ...
# 5824                    No Data             33.922918           -118.372077
# 5825  Information Not Available             33.801682           -118.396452
# 5826                    No Data             33.909404           -118.376654
# 5827  Information Not Available             33.908904           -118.377651
# 5828     www.wiseburn.k12.ca.us             33.920452           -118.378446
#
#      last_update                    address                  city  \
# 0      7/19/2021           12254 Cuesta Dr.              Cerritos
# 1      6/24/1999       16800 Shoemaker Ave.              Cerritos
# 2      11/5/2021  16534 South Carmenita Rd.              Cerritos
# 3      5/12/2016       Information Redacted              Lakewood
# 4      11/5/2021       11737 East 214th St.              Lakewood
# ...          ...                        ...                   ...
# 5824   11/5/2021          12110 Hindry Ave.             Hawthorne
# 5825  10/24/2016          300 Paseo Del Mar  Palos Verdes Estates
# 5826   11/5/2021        5504 West 135th St.             Hawthorne
# 5827  11/30/2018       13500 Aviation Blvd.             Hawthorne
# 5828   11/5/2021       13530 Aviation Blvd.             Hawthorne
#
#                   default_phone                       email  \
# 0                (562) 229-7960                     No Data
# 1                       No Data                     No Data
# 2                (562) 229-7768                     No Data
# 3          Information Redacted        Information Redacted
# 4                (562) 229-7825                     No Data
# ...                         ...                         ...
# 5824             (310) 725-2100                     No Data
# 5825  Information Not Available   Information Not Available
# 5826             (310) 725-4700                     No Data
# 5827  Information Not Available   Information Not Available
# 5828             (310) 725-2101  ts-dowgiewicz@wiseburn.org
#
#                                      original_name  \
# 0                                        ABC Adult
# 1                          ABC Evening High School
# 2                      ABC Secondary (Alternative)
# 3                    Accelerated Christian Academy
# 4                                 Aloha Elementary
# ...                                            ...
# 5824                       Juan De Anza Elementary
# 5825  Malaga Cove School - Success Learning Center
# 5826                     Richard Henry Dana Middle
# 5827                                     RISE High
# 5828                       Success Learning Center
#
#                                             simple_name
# 0                 12254-cuesta-dr-abc-adult-abc-unified
# 1     16800-shoemaker-ave-abc-evening-high-school-ab...
# 2     16534-south-carmenita-rd-abc-secondary-(altern...
# 3     information-redacted-accelerated-christian-aca...
# 4      11737-east-214th-st-aloha-elementary-abc-unified
# ...                                                 ...
# 5824  12110-hindry-ave-juan-de-anza-elementary-wiseb...
# 5825  300-paseo-del-mar-malaga-cove-school---success...
# 5826  5504-west-135th-st-richard-henry-dana-middle-w...
# 5827     13500-aviation-blvd-rise-high-wiseburn-unified
# 5828  13530-aviation-blvd-success-learning-center-wi...
#
# [5829 rows x 15 columns]

# %%
unique_schools = go_pass_schools.drop_duplicates(subset=['name'])
print(go_pass_schools.shape)
print(unique_schools.shape)

difference_in_dupes = go_pass_schools.shape[0] - unique_schools.shape[0]
# these are the number of records with the same names
print("Number of records with same names: \n "+str(difference_in_dupes))
# Out:
# (1482, 7)
# (1477, 7)
# Number of records with same names:
#  5

# %% [markdown]
# ## 3.0 Joining the `Original dataset` to the `California dataset`
#
# Here we do a blanket `left` merge where the original records get data added to it.
#
# If we want to keep the California data, then we need to switch this merge type to `inner` or `right`.
#
# #### See the Pandas merge documentation for more information:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html

# %%
def fuzzy_merge(baseFrame, compareFrame, baseKey, compareKey, threshold=86, limit=1, how='left'):
    s_mapping = {x: fuzz_utils.default_process(x) for x in compareFrame[compareKey]}

    m1 = baseFrame[baseKey].apply(lambda x: process.extract(
      fuzz_utils.default_process(x), s_mapping, limit=limit, score_cutoff=threshold, processor=None
    ))
    baseFrame['Match'] = m1

    m2 = baseFrame['Match'].apply(lambda x: ', '.join(i[2] for i in x))
    baseFrame['name'] = m2.replace("",np.nan)

    return baseFrame.merge(compareFrame, left_on='name', right_on=compareKey, how=how)

merged_df = fuzzy_merge(go_pass_schools, la_schools_df, 'name', 'simple_name',how='left')
# merged_df = fuzzy_merge(la_schools_df, go_pass_schools 'name', 'simple_name',how='right')
merged_df
# Out:
#                district_x                                             name_x  \
# 0        Centinela Valley  4859-west-el-segundo-blvd-hawthorne-high-centi...
# 1        Centinela Valley  14901-south-inglewood-ave-lawndale-high-centin...
# 2        Centinela Valley  4118-west-rosecrans-ave-leuzinger-high-centine...
# 3        Centinela Valley  4951-marine-ave-r-k-lloyde-high-centinela-vall...
# 4                 Charter                                                NaN
# ...                   ...                                                ...
# 1480              Private        1253-bishops-rd-cathedral-high-school-lausd
# 1481              Private  6361-santa-monica-blvd-the-episcopal-school-of...
# 1482              Private                                                NaN
# 1483  Santa Monica-Malibu                                                NaN
# 1484        Whittier UHSD                                                NaN
#
#                        address_x       city_x       telephone  participating  \
# 0     4859 West El Segundo Blvd.    Hawthorne  (310) 263-4400           True
# 1      14901 S. Inglewood Avenue     Lawndale  (310) 263-3100           True
# 2       4118 West Rosecrans Ave.     Lawndale  (310) 263-2200           True
# 3               4951 Marine Ave.     Lawndale  (310) 263-3264           True
# 4      461 9th Street, San Pedro    San Pedro  (310) 221-0430           True
# ...                          ...          ...             ...            ...
# 1480           1253 Bishops Road  Los Angeles  (323) 441-3113           True
# 1481     6361 Santa Monica Blvd.  Los Angeles  (323) 284-7266           True
# 1482            9650 Zelzah Ave.   Northridge  (818) 739-5231           True
# 1483                                                                    True
# 1484                                                                    True
#
#                                         original_name_x  \
# 0                                        Hawthorne High
# 1                                         Lawndale High
# 2                                        Leuzinger High
# 3                                     R. K. Lloyde High
# 4     Alliance Alice M. Baxter College-Ready High Sc...
# ...                                                 ...
# 1480                              Cathedral High School
# 1481                    Episcopal School of Los Angeles
# 1482                                  Northpoint School
# 1483
# 1484
#
#                                                   Match       county  \
# 0     [(4859 west el segundo blvd hawthorne high cen...  Los Angeles
# 1     [(14901 south inglewood ave lawndale high cent...  Los Angeles
# 2     [(4118 west rosecrans ave leuzinger high centi...  Los Angeles
# 3     [(4951 marine ave r k lloyde high centinela va...  Los Angeles
# 4                                                    []          NaN
# ...                                                 ...          ...
# 1480  [(1253 bishops rd cathedral high school lausd,...  Los Angeles
# 1481  [(6361 santa monica blvd the episcopal school ...  Los Angeles
# 1482                                                 []          NaN
# 1483                                                 []          NaN
# 1484                                                 []          NaN
#
#                        district_y  ...  website   latitude    longitude  \
# 0     Centinela Valley Union High  ...  No Data  33.916456  -118.362903
# 1     Centinela Valley Union High  ...  No Data  33.896373  -118.361369
# 2     Centinela Valley Union High  ...  No Data   33.90137   -118.34687
# 3     Centinela Valley Union High  ...  No Data  33.895165  -118.365993
# 4                             NaN  ...      NaN        NaN          NaN
# ...                           ...  ...      ...        ...          ...
# 1480                        LAUSD  ...  No Data  34.069854  -118.234286
# 1481                        LAUSD  ...  No Data  34.090998  -118.328139
# 1482                          NaN  ...      NaN        NaN          NaN
# 1483                          NaN  ...      NaN        NaN          NaN
# 1484                          NaN  ...      NaN        NaN          NaN
#
#      last_update                   address_y       city_y   default_phone  \
# 0      11/5/2021  4859 West El Segundo Blvd.    Hawthorne  (310) 263-4400
# 1      6/30/2022  14901 South Inglewood Ave.     Lawndale  (310) 263-3102
# 2      11/5/2021    4118 West Rosecrans Ave.     Lawndale  (310) 263-2208
# 3      11/5/2021            4951 Marine Ave.     Lawndale  (310) 263-3264
# 4            NaN                         NaN          NaN             NaN
# ...          ...                         ...          ...             ...
# 1480   6/27/2022            1253 Bishops Rd.  Los Angeles  (323) 225-2438
# 1481   6/28/2022     6361 Santa Monica Blvd.  Los Angeles  (323) 462-3752
# 1482         NaN                         NaN          NaN             NaN
# 1483         NaN                         NaN          NaN             NaN
# 1484         NaN                         NaN          NaN             NaN
#
#                     email                      original_name_y  \
# 0                 No Data                       Hawthorne High
# 1                 No Data                        Lawndale High
# 2                 No Data                       Leuzinger High
# 3                 No Data                    R. K. Lloyde High
# 4                     NaN                                  NaN
# ...                   ...                                  ...
# 1480    brjohnm@chsla.org                Cathedral High School
# 1481  registrar@es-la.com  The Episcopal School of Los Angeles
# 1482                  NaN                                  NaN
# 1483                  NaN                                  NaN
# 1484                  NaN                                  NaN
#
#                                             simple_name
# 0     4859-west-el-segundo-blvd-hawthorne-high-centi...
# 1     14901-south-inglewood-ave-lawndale-high-centin...
# 2     4118-west-rosecrans-ave-leuzinger-high-centine...
# 3     4951-marine-ave-r-k-lloyde-high-centinela-vall...
# 4                                                   NaN
# ...                                                 ...
# 1480        1253-bishops-rd-cathedral-high-school-lausd
# 1481  6361-santa-monica-blvd-the-episcopal-school-of...
# 1482                                                NaN
# 1483                                                NaN
# 1484                                                NaN
#
# [1485 rows x 23 columns]

# %% [markdown]
# ## 4.0 Cleaning up of Merged Data
#
# The steps are as follows:
# 1. Assign the full name the original name and the district
#    - Note: you can also use the California district names instead by uncommenting the `Altenative` line
# 2. Process alternative method of naming where district names are only added if there are duplicates
# 3. Set the final `phone` column to default to the original data's `telephone` column
# 4. Get the match score from rapidfuzz

# %%
# 1. Default name processing
merged_df['full_name'] = merged_df['original_name_x'] + ' (' + merged_df['district_x'] + ')'

# 1b. alternative approach: uncomment below to use the California district names instead
# merged_df['full_name']  = merged_df['original_name_x'] + ' (' + merged_df['district_y'] + ')'

# 2. Alternative school name field processing
# Flag duplicated records
merged_df['duped'] = merged_df.duplicated(['original_name_x'],keep=False)

# `full_name_some` is the option where there are district names for only duplicated records.
merged_df.loc[merged_df['duped'] == False, 'full_name_some'] = merged_df['original_name_x']
merged_df.loc[merged_df['duped'] == True, 'full_name_some'] = merged_df['original_name_x'] + ' (' + merged_df['district_y'] + ')'

# 3. Phone number processing
merged_df['phone'] = merged_df['telephone']

# if there is less than 4 characters in that column then set it to the California's phone numbers i.e. 'default phone' column
merged_df.loc[merged_df['phone'].str.len() < 4, 'phone'] = merged_df['default_phone']

# 4. Match score processing
merged_df['score'] = merged_df['Match'].astype('string').str.split(",").str[1]

merged_df
# Out:
#                district_x                                             name_x  \
# 0        Centinela Valley  4859-west-el-segundo-blvd-hawthorne-high-centi...
# 1        Centinela Valley  14901-south-inglewood-ave-lawndale-high-centin...
# 2        Centinela Valley  4118-west-rosecrans-ave-leuzinger-high-centine...
# 3        Centinela Valley  4951-marine-ave-r-k-lloyde-high-centinela-vall...
# 4                 Charter                                                NaN
# ...                   ...                                                ...
# 1480              Private        1253-bishops-rd-cathedral-high-school-lausd
# 1481              Private  6361-santa-monica-blvd-the-episcopal-school-of...
# 1482              Private                                                NaN
# 1483  Santa Monica-Malibu                                                NaN
# 1484        Whittier UHSD                                                NaN
#
#                        address_x       city_x       telephone  participating  \
# 0     4859 West El Segundo Blvd.    Hawthorne  (310) 263-4400           True
# 1      14901 S. Inglewood Avenue     Lawndale  (310) 263-3100           True
# 2       4118 West Rosecrans Ave.     Lawndale  (310) 263-2200           True
# 3               4951 Marine Ave.     Lawndale  (310) 263-3264           True
# 4      461 9th Street, San Pedro    San Pedro  (310) 221-0430           True
# ...                          ...          ...             ...            ...
# 1480           1253 Bishops Road  Los Angeles  (323) 441-3113           True
# 1481     6361 Santa Monica Blvd.  Los Angeles  (323) 284-7266           True
# 1482            9650 Zelzah Ave.   Northridge  (818) 739-5231           True
# 1483                                                                    True
# 1484                                                                    True
#
#                                         original_name_x  \
# 0                                        Hawthorne High
# 1                                         Lawndale High
# 2                                        Leuzinger High
# 3                                     R. K. Lloyde High
# 4     Alliance Alice M. Baxter College-Ready High Sc...
# ...                                                 ...
# 1480                              Cathedral High School
# 1481                    Episcopal School of Los Angeles
# 1482                                  Northpoint School
# 1483
# 1484
#
#                                                   Match       county  \
# 0     [(4859 west el segundo blvd hawthorne high cen...  Los Angeles
# 1     [(14901 south inglewood ave lawndale high cent...  Los Angeles
# 2     [(4118 west rosecrans ave leuzinger high centi...  Los Angeles
# 3     [(4951 marine ave r k lloyde high centinela va...  Los Angeles
# 4                                                    []          NaN
# ...                                                 ...          ...
# 1480  [(1253 bishops rd cathedral high school lausd,...  Los Angeles
# 1481  [(6361 santa monica blvd the episcopal school ...  Los Angeles
# 1482                                                 []          NaN
# 1483                                                 []          NaN
# 1484                                                 []          NaN
#
#                        district_y  ...       city_y   default_phone  \
# 0     Centinela Valley Union High  ...    Hawthorne  (310) 263-4400
# 1     Centinela Valley Union High  ...     Lawndale  (310) 263-3102
# 2     Centinela Valley Union High  ...     Lawndale  (310) 263-2208
# 3     Centinela Valley Union High  ...     Lawndale  (310) 263-3264
# 4                             NaN  ...          NaN             NaN
# ...                           ...  ...          ...             ...
# 1480                        LAUSD  ...  Los Angeles  (323) 225-2438
# 1481                        LAUSD  ...  Los Angeles  (323) 462-3752
# 1482                          NaN  ...          NaN             NaN
# 1483                          NaN  ...          NaN             NaN
# 1484                          NaN  ...          NaN             NaN
#
#                     email                      original_name_y  \
# 0                 No Data                       Hawthorne High
# 1                 No Data                        Lawndale High
# 2                 No Data                       Leuzinger High
# 3                 No Data                    R. K. Lloyde High
# 4                     NaN                                  NaN
# ...                   ...                                  ...
# 1480    brjohnm@chsla.org                Cathedral High School
# 1481  registrar@es-la.com  The Episcopal School of Los Angeles
# 1482                  NaN                                  NaN
# 1483                  NaN                                  NaN
# 1484                  NaN                                  NaN
#
#                                             simple_name  \
# 0     4859-west-el-segundo-blvd-hawthorne-high-centi...
# 1     14901-south-inglewood-ave-lawndale-high-centin...
# 2     4118-west-rosecrans-ave-leuzinger-high-centine...
# 3     4951-marine-ave-r-k-lloyde-high-centinela-vall...
# 4                                                   NaN
# ...                                                 ...
# 1480        1253-bishops-rd-cathedral-high-school-lausd
# 1481  6361-santa-monica-blvd-the-episcopal-school-of...
# 1482                                                NaN
# 1483                                                NaN
# 1484                                                NaN
#
#                                               full_name  duped  \
# 0                     Hawthorne High (Centinela Valley)  False
# 1                      Lawndale High (Centinela Valley)  False
# 2                     Leuzinger High (Centinela Valley)  False
# 3                  R. K. Lloyde High (Centinela Valley)  False
# 4     Alliance Alice M. Baxter College-Ready High Sc...  False
# ...                                                 ...    ...
# 1480                    Cathedral High School (Private)  False
# 1481          Episcopal School of Los Angeles (Private)  False
# 1482                        Northpoint School (Private)  False
# 1483                              (Santa Monica-Malibu)   True
# 1484                                    (Whittier UHSD)   True
#
#                                          full_name_some           phone  \
# 0                                        Hawthorne High  (310) 263-4400
# 1                                         Lawndale High  (310) 263-3100
# 2                                        Leuzinger High  (310) 263-2200
# 3                                     R. K. Lloyde High  (310) 263-3264
# 4     Alliance Alice M. Baxter College-Ready High Sc...  (310) 221-0430
# ...                                                 ...             ...
# 1480                              Cathedral High School  (323) 441-3113
# 1481                    Episcopal School of Los Angeles  (323) 284-7266
# 1482                                  Northpoint School  (818) 739-5231
# 1483                                                NaN             NaN
# 1484                                                NaN             NaN
#
#                    score
# 0                   95.0
# 1      86.53465346534652
# 2                   95.0
# 3                   95.0
# 4                    NaN
# ...                  ...
# 1480   86.66666666666667
# 1481   88.88888888888889
# 1482                 NaN
# 1483                 NaN
# 1484                 NaN
#
# [1485 rows x 28 columns]

# %% [markdown]
# ## 5.0 Final Column Selection
# Here we select the final data columns for our outputs, with `_x` suffixes representing the original Metro dataset and `_y` suffixes representing the California schools dataset.
#
# - "district_x"
# - "district_y"
# - "original_name_x"
# - "original_name_y"
# - "status"
# - 'closed_date'
# - "full_name"
# - "full_name_some"
# - "participating"
# - "address_x"
# - "address_y"
# - "city_x"
# - "city_y"
# - 'address_y'
# - 'city_y'
# - "score"
# - "duped"
# - 'phone'
# - 'email'
# - 'website'
# - 'latitude'
# - 'longitude'
# - 'last_update'

# %%
final_columns = {
    "full_name":"school_name",
    "full_name_some":"school_name_with_some_districts_attached",
}

final_df = merged_df[["district_x","district_y","original_name_x","original_name_y","status",'closed_date',
       "full_name","full_name_some","participating","address_x","address_y","city_x","city_y","score","duped",'phone', 'email',
       'website', 'latitude', 'longitude', 'last_update']]
final_df.rename(inplace=True, columns=final_columns)
final_df.reset_index(inplace=True)
final_df.index.names = ['id']

final_df
# Out:
# c:\Users\hikou\.conda\envs\metro\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#         id           district_x                   district_y  \
# id
# 0        0     Centinela Valley  Centinela Valley Union High
# 1        1     Centinela Valley  Centinela Valley Union High
# 2        2     Centinela Valley  Centinela Valley Union High
# 3        3     Centinela Valley  Centinela Valley Union High
# 4        4              Charter                          NaN
# ...    ...                  ...                          ...
# 1480  1480              Private                        LAUSD
# 1481  1481              Private                        LAUSD
# 1482  1482              Private                          NaN
# 1483  1483  Santa Monica-Malibu                          NaN
# 1484  1484        Whittier UHSD                          NaN
#
#                                         original_name_x  \
# id
# 0                                        Hawthorne High
# 1                                         Lawndale High
# 2                                        Leuzinger High
# 3                                     R. K. Lloyde High
# 4     Alliance Alice M. Baxter College-Ready High Sc...
# ...                                                 ...
# 1480                              Cathedral High School
# 1481                    Episcopal School of Los Angeles
# 1482                                  Northpoint School
# 1483
# 1484
#
#                           original_name_y  status closed_date  \
# id
# 0                          Hawthorne High  Active     No Data
# 1                           Lawndale High  Active     No Data
# 2                          Leuzinger High  Active     No Data
# 3                       R. K. Lloyde High  Active     No Data
# 4                                     NaN     NaN         NaN
# ...                                   ...     ...         ...
# 1480                Cathedral High School  Active     No Data
# 1481  The Episcopal School of Los Angeles  Active     No Data
# 1482                                  NaN     NaN         NaN
# 1483                                  NaN     NaN         NaN
# 1484                                  NaN     NaN         NaN
#
#                                             school_name  \
# id
# 0                     Hawthorne High (Centinela Valley)
# 1                      Lawndale High (Centinela Valley)
# 2                     Leuzinger High (Centinela Valley)
# 3                  R. K. Lloyde High (Centinela Valley)
# 4     Alliance Alice M. Baxter College-Ready High Sc...
# ...                                                 ...
# 1480                    Cathedral High School (Private)
# 1481          Episcopal School of Los Angeles (Private)
# 1482                        Northpoint School (Private)
# 1483                              (Santa Monica-Malibu)
# 1484                                    (Whittier UHSD)
#
#                school_name_with_some_districts_attached  participating  ...  \
# id                                                                      ...
# 0                                        Hawthorne High           True  ...
# 1                                         Lawndale High           True  ...
# 2                                        Leuzinger High           True  ...
# 3                                     R. K. Lloyde High           True  ...
# 4     Alliance Alice M. Baxter College-Ready High Sc...           True  ...
# ...                                                 ...            ...  ...
# 1480                              Cathedral High School           True  ...
# 1481                    Episcopal School of Los Angeles           True  ...
# 1482                                  Northpoint School           True  ...
# 1483                                                NaN           True  ...
# 1484                                                NaN           True  ...
#
#            city_x       city_y               score  duped           phone  \
# id
# 0       Hawthorne    Hawthorne                95.0  False  (310) 263-4400
# 1        Lawndale     Lawndale   86.53465346534652  False  (310) 263-3100
# 2        Lawndale     Lawndale                95.0  False  (310) 263-2200
# 3        Lawndale     Lawndale                95.0  False  (310) 263-3264
# 4       San Pedro          NaN                 NaN  False  (310) 221-0430
# ...           ...          ...                 ...    ...             ...
# 1480  Los Angeles  Los Angeles   86.66666666666667  False  (323) 441-3113
# 1481  Los Angeles  Los Angeles   88.88888888888889  False  (323) 284-7266
# 1482   Northridge          NaN                 NaN  False  (818) 739-5231
# 1483                       NaN                 NaN   True             NaN
# 1484                       NaN                 NaN   True             NaN
#
#                     email  website   latitude    longitude last_update
# id
# 0                 No Data  No Data  33.916456  -118.362903   11/5/2021
# 1                 No Data  No Data  33.896373  -118.361369   6/30/2022
# 2                 No Data  No Data   33.90137   -118.34687   11/5/2021
# 3                 No Data  No Data  33.895165  -118.365993   11/5/2021
# 4                     NaN      NaN        NaN          NaN         NaN
# ...                   ...      ...        ...          ...         ...
# 1480    brjohnm@chsla.org  No Data  34.069854  -118.234286   6/27/2022
# 1481  registrar@es-la.com  No Data  34.090998  -118.328139   6/28/2022
# 1482                  NaN      NaN        NaN          NaN         NaN
# 1483                  NaN      NaN        NaN          NaN         NaN
# 1484                  NaN      NaN        NaN          NaN         NaN
#
# [1485 rows x 22 columns]

# %%
final_df.columns
# Out:
# Index(['district_x', 'district_y', 'original_name_x', 'original_name_y',
#        'status', 'closed_date', 'school_name',
#        'school_name_with_some_districts_attached', 'participating',
#        'address_x', 'address_y', 'city_x', 'city_y', 'address_y', 'city_y',
#        'score', 'duped', 'phone', 'email', 'website', 'latitude', 'longitude',
#        'last_update'],
#       dtype='object')

# %% [markdown]
# ## 5.0 Final Output
# Using today's date and the csv file extension we will output the file to the data directory.
#
# We also split the data using `to_json` in pandas, more info here:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_json.html

# %%
today = str(datetime.now().date())
outfile_extension = ".csv"
output_file_name = "../data/go_pass_schools_merged_with_california_dataset_"+today+outfile_extension

final_df.to_csv(output_file_name)

#create JSON file oriented by split columns
json_file = final_df.to_json(orient='split')
output_json = "../data/go_pass_schools_merged_with_california_dataset_"+today+".json"
with open(output_json, 'w') as f:
    f.write(json_file)

#create JSON file oriented by records
output_json_v2 = "../data/go_pass_schools_merged_with_california_dataset_"+today+"orient_records.json"
json_file2 = final_df.to_json(orient='records',index=True) 
with open(output_json_v2, 'w') as f2:
    f2.write(json_file2)
