# %% [markdown]
# # Jupyter Notebook for converting the Go Pass Data

# %% [markdown]
# ## 1.0 Load in modules
#
# We are using pandas and the numpy libraries to read and process the data.
#
# Then we will use the `rapidfuzz` library to caclulate close matches to the strings so that we can join the information.
#
# Using other popular fuzzy-string matching libraries like `fuzzball` takes over 3 hours to process as the alogrithim used takes the number of records to the `n`th power!! (i.e. comparing 1000 records processes 1000^1000!!!) `rapidfuzz` has a better algorithm that trims this town to 3 - 4 minutes!

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from rapidfuzz import process, utils as fuzz_utils

GOOGLE_SHEET_URL = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSWbwrsqF-c---4lfw0LZWymd-f8sy8sLYkXgzh0OyeGATWwrvv7V1Mq5BcApn7F_-WYKP1KXy5shKw/pub?gid=376323488&single=true&output=csv'

# %% [markdown]
# ## 2.0 Format Go Pass Data
#
# We will be extracting the following fields:
#
# - District
# - School
# - Address
# - City
# - Participating
#
# We create a simplfied field called `name` based on the `street address`, `school name`, and `district`. This field is formatted to be all lowercase with spaces replaced with `-` to make matching easier.

# %%
go_pass_schools = pd.read_csv(GOOGLE_SHEET_URL,
    usecols={'district_x','original_name_x','address_x','city_x','phone','email'})
go_pass_schools.columns = ["district","name","address","city","phone","email"]

go_pass_schools = go_pass_schools.fillna('')
go_pass_schools['original_name'] = go_pass_schools['name']
simple_district = go_pass_schools['district'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
# go_pass_schools['name'] = go_pass_schools['name'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')+"-"+simple_district


# simple_address = go_pass_schools['address'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
go_pass_schools['simple_address'] = go_pass_schools['address'].str.split().str.get(0)
go_pass_schools['simple_address'] = go_pass_schools['simple_address'].fillna('')


simple_name = go_pass_schools['name'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')


# go_pass_schools.loc[(go_pass_schools['name'].str.len() > 1),'name'] = simple_address+"-"+simple_name+"-"+simple_district
go_pass_schools['name'] = go_pass_schools['simple_address']+"-"+simple_name

go_pass_schools
# Out:
#                  district                                               name  \
# 0        Centinela Valley                                4859-hawthorne-high
# 1        Centinela Valley                                14901-lawndale-high
# 2        Centinela Valley                                4118-leuzinger-high
# 3        Centinela Valley                               4951-r-k-lloyde-high
# 4                 Charter  461-alliance-alice-m-baxter-college-ready-high...
# ...                   ...                                                ...
# 1480              Private                         1253-cathedral-high-school
# 1481              Private               6361-episcopal-school-of-los-angeles
# 1482              Private                             9650-northpoint-school
# 1483  Santa Monica-Malibu                                                  -
# 1484        Whittier UHSD                                                  -
#
#                          address         city           phone  \
# 0     4859 West El Segundo Blvd.    Hawthorne  (310) 263-4400
# 1      14901 S. Inglewood Avenue     Lawndale  (310) 263-3100
# 2       4118 West Rosecrans Ave.     Lawndale  (310) 263-2200
# 3               4951 Marine Ave.     Lawndale  (310) 263-3264
# 4      461 9th Street, San Pedro    San Pedro  (310) 221-0430
# ...                          ...          ...             ...
# 1480           1253 Bishops Road  Los Angeles  (323) 441-3113
# 1481     6361 Santa Monica Blvd.  Los Angeles  (323) 284-7266
# 1482            9650 Zelzah Ave.   Northridge  (818) 739-5231
# 1483
# 1484
#
#                     email                                      original_name  \
# 0                 No Data                                     Hawthorne High
# 1                 No Data                                      Lawndale High
# 2                 No Data                                     Leuzinger High
# 3                 No Data                                  R. K. Lloyde High
# 4                          Alliance Alice M. Baxter College-Ready High Sc...
# ...                   ...                                                ...
# 1480    brjohnm@chsla.org                              Cathedral High School
# 1481  registrar@es-la.com                    Episcopal School of Los Angeles
# 1482                                                       Northpoint School
# 1483
# 1484
#
#      simple_address
# 0              4859
# 1             14901
# 2              4118
# 3              4951
# 4               461
# ...             ...
# 1480           1253
# 1481           6361
# 1482           9650
# 1483
# 1484
#
# [1485 rows x 8 columns]

# %% [markdown]
# ### 2.1 Format California Schools data
#
# We create a simplfied field called `simple name` based on the `street address`, `school name`, and `district`. This field is formatted to be all lowercase with spaces replaced with `-` to make matching easier.
#
# #### Source for California schools data
#
# https://www.cde.ca.gov/SchoolDirectory/ExportSelect?simpleSearch=N&address=&city=&counties=&districts=&cdscode=&charter=&magnet=&name=&nps=&search=2&zip=&yearround=&status=1%2C2&types=&order=1&multilingual=&qsc=3549&qdc=3549
#
# August 2022

# %%
california_schools_data = "../data/TapData.csv"

california_schools = pd.read_csv(california_schools_data)
    # usecols={'school','district','street','city','state',"zip"})
# california_schools.columns = ["school","district","address","city","state","zip"]

la_schools_df = california_schools.fillna('')
# la_schools_df

la_schools_df['original_name'] = la_schools_df['school']
la_schools_df['name'] = la_schools_df['school'].replace({'\([a-zA-Z\s\.\-\/]*\(*[a-zA-Z\s\.\-\/]*\)*[a-zA-Z\s\.\-\/]*\)$'},'',regex=True)
# la_schools_df.loc[la_schools_df['district'] == "Los Angeles Unified", 'district'] = "LAUSD"
simple_district = la_schools_df['district'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')


# simple_address = la_schools_df['street'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')
la_schools_df['simple_address'] = la_schools_df['street'].str.split().str.get(0)
la_schools_df['simple_address'] = la_schools_df['simple_address'].fillna('')


# simple_name = la_schools_df['school'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')+"-"
simple_name = la_schools_df['name'].str.lower().str.replace(" ","-").str.replace(".","").str.replace('"','')


# la_schools_df['simple_name'] = simple_address+"-"+simple_name+"-"+simple_district
la_schools_df['simple_name'] = la_schools_df['simple_address']+"-"+simple_name


la_schools_df
# Out:
#       rowid                                             school  \
# 0         1                     Palms Elementary (ABC Unified)
# 1         2                   Ross (Faye) Middle (ABC Unified)
# 2         3         Stowers(Cecil B.) Elementary (ABC Unified)
# 3         4          Tetzlaff (Martin B.) Middle (ABC Unified)
# 4         5   Tracy (Wilbur) High (Continuation) (ABC Unified)
# ...     ...                                                ...
# 3146   3147  YouthBuild - Norwalk (YouthBuild Charter Schoo...
# 3147   3148  YouthBuild - Palmdale (YouthBuild Charter Scho...
# 3148   3149  YouthBuild - Pomona (YouthBuild Charter School...
# 3149   3150  YouthBuild - South LA (YouthBuild Charter Scho...
# 3150   3151  YouthBuild - Youth Justice Coalition (YouthBui...
#
#                                        district                     street  \
# 0                                   ABC Unified       12445 East 207th St.
# 1                                   ABC Unified          17707 Elaine Ave.
# 2                                   ABC Unified            13350 Beach St.
# 3                                   ABC Unified   12351 East Del Amo Blvd.
# 4                                   ABC Unified           12222 Cuesta Dr.
# ...                                         ...                        ...
# 3146  YouthBuild Charter Schools of Los Angeles            12124 Front St.
# 3147  YouthBuild Charter Schools of Los Angeles         38626 9th St. East
# 3148  YouthBuild Charter Schools of Los Angeles           305 E Arrow Hwy.
# 3149  YouthBuild Charter Schools of Los Angeles  400 West Washington Blvd.
# 3150  YouthBuild Charter Schools of Los Angeles       7625 S. Central Ave.
#
#              city state         zip  \
# 0        Lakewood    CA  90715-1619
# 1         Artesia    CA  90701-4018
# 2        Cerritos    CA  90703-1331
# 3        Cerritos    CA  90703-7635
# 4        Cerritos    CA  90703-2801
# ...           ...   ...         ...
# 3146      Norwalk    CA       90650
# 3147     Palmdale    CA       93550
# 3148       Pomona    CA       91767
# 3149  Los Angeles    CA       90015
# 3150  Los Angeles    CA       90001
#
#                                           original_name  \
# 0                        Palms Elementary (ABC Unified)
# 1                      Ross (Faye) Middle (ABC Unified)
# 2            Stowers(Cecil B.) Elementary (ABC Unified)
# 3             Tetzlaff (Martin B.) Middle (ABC Unified)
# 4      Tracy (Wilbur) High (Continuation) (ABC Unified)
# ...                                                 ...
# 3146  YouthBuild - Norwalk (YouthBuild Charter Schoo...
# 3147  YouthBuild - Palmdale (YouthBuild Charter Scho...
# 3148  YouthBuild - Pomona (YouthBuild Charter School...
# 3149  YouthBuild - South LA (YouthBuild Charter Scho...
# 3150  YouthBuild - Youth Justice Coalition (YouthBui...
#
#                                        name simple_address  \
# 0                         Palms Elementary           12445
# 1                       Ross (Faye) Middle           17707
# 2             Stowers(Cecil B.) Elementary           13350
# 3              Tetzlaff (Martin B.) Middle           12351
# 4       Tracy (Wilbur) High (Continuation)           12222
# ...                                     ...            ...
# 3146                  YouthBuild - Norwalk           12124
# 3147                 YouthBuild - Palmdale           38626
# 3148                   YouthBuild - Pomona             305
# 3149                 YouthBuild - South LA             400
# 3150  YouthBuild - Youth Justice Coalition            7625
#
#                                      simple_name
# 0                        12445-palms-elementary-
# 1                      17707-ross-(faye)-middle-
# 2             13350-stowers(cecil-b)-elementary-
# 3              12351-tetzlaff-(martin-b)-middle-
# 4      12222-tracy-(wilbur)-high-(continuation)-
# ...                                          ...
# 3146                 12124-youthbuild---norwalk-
# 3147                38626-youthbuild---palmdale-
# 3148                    305-youthbuild---pomona-
# 3149                  400-youthbuild---south-la-
# 3150  7625-youthbuild---youth-justice-coalition-
#
# [3151 rows x 11 columns]

# %%
# unique_schools = go_pass_schools.drop_duplicates(subset=['original_name'])
# print(go_pass_schools.shape)
# print(unique_schools.shape)

# difference_in_dupes = go_pass_schools.shape[0] - unique_schools.shape[0]
# # these are the number of records with the same names
# print("Number of records with same names: \n "+str(difference_in_dupes))

# %% [markdown]
# ## 3.0 Joining the `Original dataset` to the `California dataset`
#
# Here we do a blanket `left` merge where the original records get data added to it.
#
# If we want to keep the California data, then we need to switch this merge type to `inner` or `right`.
#
# #### See the Pandas merge documentation for more information:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html

# %%
def m1_lambda(x, s_mapping, limit, threshold):
  print(x)
  process.extract(
    fuzz_utils.default_process(x), s_mapping, limit=limit, score_cutoff=threshold, processor=None
  )


def fuzzy_merge(baseFrame, compareFrame, baseKey, compareKey, threshold=86, limit=1, how='left'):
    s_mapping = {x: fuzz_utils.default_process(x) for x in compareFrame[compareKey]}
    m1 = baseFrame[baseKey].apply(lambda x: process.extract(
      fuzz_utils.default_process(x), s_mapping, limit=limit, score_cutoff=threshold, processor=None
    ))
    baseFrame['Match'] = m1

    m2 = baseFrame['Match'].apply(lambda x: ', '.join(i[2] for i in x))
    
    # baseFrame['name'] = m2.replace("",np.nan)
    baseFrame[baseKey] = m2.replace("",np.nan)

    # baseFrame['school'] = m2['school']
    # return baseFrame.merge(compareFrame, left_on='name', right_on=compareKey, how=how)
    return baseFrame.merge(compareFrame, left_on=baseKey, right_on=compareKey, how=how)

merged_df = fuzzy_merge(go_pass_schools, la_schools_df, 'name', 'simple_name',how='left')
# merged_df = fuzzy_merge(go_pass_schools, la_schools_df, 'original_name', 'name',how='left')
# merged_df = fuzzy_merge(la_schools_df, go_pass_schools, 'name', 'original_name',how='right')
merged_df
# Out:
#                district_x                                     name_x  \
# 0        Centinela Valley                       4859-hawthorne-high-
# 1        Centinela Valley                       14901-lawndale-high-
# 2        Centinela Valley                       4118-leuzinger-high-
# 3        Centinela Valley                      4951-r-k-lloyde-high-
# 4                 Charter                                        NaN
# ...                   ...                                        ...
# 1480              Private                1253-cathedral-high-school-
# 1481              Private  6325-the-episcopal-school-of-los-angeles-
# 1482              Private                    9650-northpoint-school-
# 1483  Santa Monica-Malibu                                        NaN
# 1484        Whittier UHSD                                        NaN
#
#                          address       city_x           phone  \
# 0     4859 West El Segundo Blvd.    Hawthorne  (310) 263-4400
# 1      14901 S. Inglewood Avenue     Lawndale  (310) 263-3100
# 2       4118 West Rosecrans Ave.     Lawndale  (310) 263-2200
# 3               4951 Marine Ave.     Lawndale  (310) 263-3264
# 4      461 9th Street, San Pedro    San Pedro  (310) 221-0430
# ...                          ...          ...             ...
# 1480           1253 Bishops Road  Los Angeles  (323) 441-3113
# 1481     6361 Santa Monica Blvd.  Los Angeles  (323) 284-7266
# 1482            9650 Zelzah Ave.   Northridge  (818) 739-5231
# 1483
# 1484
#
#                     email                                    original_name_x  \
# 0                 No Data                                     Hawthorne High
# 1                 No Data                                      Lawndale High
# 2                 No Data                                     Leuzinger High
# 3                 No Data                                  R. K. Lloyde High
# 4                          Alliance Alice M. Baxter College-Ready High Sc...
# ...                   ...                                                ...
# 1480    brjohnm@chsla.org                              Cathedral High School
# 1481  registrar@es-la.com                    Episcopal School of Los Angeles
# 1482                                                       Northpoint School
# 1483
# 1484
#
#      simple_address_x                                              Match  \
# 0                4859  [(4859 hawthorne high, 100.0, 4859-hawthorne-h...
# 1               14901  [(14901 lawndale high, 100.0, 14901-lawndale-h...
# 2                4118  [(4118 leuzinger high, 100.0, 4118-leuzinger-h...
# 3                4951  [(4951 r k lloyde high, 100.0, 4951-r-k-lloyde...
# 4                 461                                                 []
# ...               ...                                                ...
# 1480             1253  [(1253 cathedral high school, 100.0, 1253-cath...
# 1481             6361  [(6325 the episcopal school of los angeles, 89...
# 1482             9650  [(9650 northpoint school, 100.0, 9650-northpoi...
# 1483                                                                  []
# 1484                                                                  []
#
#       rowid                                             school  \
# 0     306.0       Hawthorne High (Centinela Valley Union High)
# 1     307.0        Lawndale High (Centinela Valley Union High)
# 2     308.0       Leuzinger High (Centinela Valley Union High)
# 3     310.0    R. K. Lloyde High (Centinela Valley Union High)
# 4       NaN                                                NaN
# ...     ...                                                ...
# 1480  862.0  Cathedral High School (Independent Charter Sch...
# 1481  825.0  The Episcopal School of Los Angeles (Independe...
# 1482  843.0  Northpoint School (Independent Charter Schools...
# 1483    NaN                                                NaN
# 1484    NaN                                                NaN
#
#                                 district_y                      street  \
# 0              Centinela Valley Union High  4859 West El Segundo Blvd.
# 1              Centinela Valley Union High  14901 South Inglewood Ave.
# 2              Centinela Valley Union High    4118 West Rosecrans Ave.
# 3              Centinela Valley Union High            4951 Marine Ave.
# 4                                      NaN                         NaN
# ...                                    ...                         ...
# 1480  Independent Charter Schools District            1253 Bishops Rd.
# 1481  Independent Charter Schools District     6325 Santa Monica Blvd.
# 1482  Independent Charter Schools District            9650 Zelzah Ave.
# 1483                                   NaN                         NaN
# 1484                                   NaN                         NaN
#
#            city_y state         zip  \
# 0       Hawthorne    CA  90250-4204
# 1        Lawndale    CA  90260-1251
# 2        Lawndale    CA  90260-1601
# 3        Lawndale    CA  90260-1251
# 4             NaN   NaN         NaN
# ...           ...   ...         ...
# 1480  Los Angeles    CA  90012-1453
# 1481  Los Angeles    CA  90038-1694
# 1482   Northridge    CA  91325-2003
# 1483          NaN   NaN         NaN
# 1484          NaN   NaN         NaN
#
#                                         original_name_y  \
# 0          Hawthorne High (Centinela Valley Union High)
# 1           Lawndale High (Centinela Valley Union High)
# 2          Leuzinger High (Centinela Valley Union High)
# 3       R. K. Lloyde High (Centinela Valley Union High)
# 4                                                   NaN
# ...                                                 ...
# 1480  Cathedral High School (Independent Charter Sch...
# 1481  The Episcopal School of Los Angeles (Independe...
# 1482  Northpoint School (Independent Charter Schools...
# 1483                                                NaN
# 1484                                                NaN
#
#                                     name_y simple_address_y  \
# 0                          Hawthorne High              4859
# 1                           Lawndale High             14901
# 2                          Leuzinger High              4118
# 3                       R. K. Lloyde High              4951
# 4                                      NaN              NaN
# ...                                    ...              ...
# 1480                Cathedral High School              1253
# 1481  The Episcopal School of Los Angeles              6325
# 1482                    Northpoint School              9650
# 1483                                   NaN              NaN
# 1484                                   NaN              NaN
#
#                                     simple_name
# 0                          4859-hawthorne-high-
# 1                          14901-lawndale-high-
# 2                          4118-leuzinger-high-
# 3                         4951-r-k-lloyde-high-
# 4                                           NaN
# ...                                         ...
# 1480                1253-cathedral-high-school-
# 1481  6325-the-episcopal-school-of-los-angeles-
# 1482                    9650-northpoint-school-
# 1483                                        NaN
# 1484                                        NaN
#
# [1485 rows x 20 columns]

# %% [markdown]
# ## 4.0 Cleaning up of Merged Data
#
# The steps are as follows:
# 1. Assign the full name the original name and the district
#    - Note: you can also use the California district names instead by uncommenting the `Altenative` line
# 2. Process alternative method of naming where district names are only added if there are duplicates
# 3. Set the final `phone` column to default to the original data's `telephone` column
# 4. Get the match score from rapidfuzz

# %%
merged_df['rowid'].fillna(0, inplace=True)
merged_df['rowid'] = merged_df['rowid'].astype('int64')

# %%
# 1. Default name processing
# merged_df['full_name'] = merged_df['original_name_x'] + ' (' + merged_df['district_x'] + ')'
merged_df.loc[merged_df['rowid'] == 0, 'school'] = merged_df['original_name_x'] + ' (' + merged_df['district_x'] + ')'
merged_df.loc[merged_df['rowid'] == 0, 'district'] = merged_df['district_x']
merged_df['participating'] = True
# 1b. alternative approach: uncomment below to use the California district names instead
# merged_df['full_name']  = merged_df['original_name_x'] + ' (' + merged_df['district_y'] + ')'

# 2. Alternative school name field processing
# Flag duplicated records
merged_df['duped'] = merged_df.duplicated(['original_name_x'],keep=False)

# `full_name_some` is the option where there are district names for only duplicated records.
# merged_df.loc[merged_df['duped'] == False, 'full_name_some'] = merged_df['original_name_x']
# merged_df.loc[merged_df['duped'] == True, 'full_name_some'] = merged_df['original_name_x'] + ' (' + merged_df['district_y'] + ')'

# 3. Phone number processing
# merged_df['phone'] = merged_df['telephone']

# if there is less than 4 characters in that column then set it to the California's phone numbers i.e. 'default phone' column
# merged_df.loc[merged_df['phone'].str.len() < 4, 'phone'] = merged_df['default_phone']

# 4. Match score processing
merged_df['score'] = merged_df['Match'].astype('string').str.split(",").str[1]

merged_df
# Out:
#                district_x                                     name_x  \
# 0        Centinela Valley                       4859-hawthorne-high-
# 1        Centinela Valley                       14901-lawndale-high-
# 2        Centinela Valley                       4118-leuzinger-high-
# 3        Centinela Valley                      4951-r-k-lloyde-high-
# 4                 Charter                                        NaN
# ...                   ...                                        ...
# 1480              Private                1253-cathedral-high-school-
# 1481              Private  6325-the-episcopal-school-of-los-angeles-
# 1482              Private                    9650-northpoint-school-
# 1483  Santa Monica-Malibu                                        NaN
# 1484        Whittier UHSD                                        NaN
#
#                          address       city_x           phone  \
# 0     4859 West El Segundo Blvd.    Hawthorne  (310) 263-4400
# 1      14901 S. Inglewood Avenue     Lawndale  (310) 263-3100
# 2       4118 West Rosecrans Ave.     Lawndale  (310) 263-2200
# 3               4951 Marine Ave.     Lawndale  (310) 263-3264
# 4      461 9th Street, San Pedro    San Pedro  (310) 221-0430
# ...                          ...          ...             ...
# 1480           1253 Bishops Road  Los Angeles  (323) 441-3113
# 1481     6361 Santa Monica Blvd.  Los Angeles  (323) 284-7266
# 1482            9650 Zelzah Ave.   Northridge  (818) 739-5231
# 1483
# 1484
#
#                     email                                    original_name_x  \
# 0                 No Data                                     Hawthorne High
# 1                 No Data                                      Lawndale High
# 2                 No Data                                     Leuzinger High
# 3                 No Data                                  R. K. Lloyde High
# 4                          Alliance Alice M. Baxter College-Ready High Sc...
# ...                   ...                                                ...
# 1480    brjohnm@chsla.org                              Cathedral High School
# 1481  registrar@es-la.com                    Episcopal School of Los Angeles
# 1482                                                       Northpoint School
# 1483
# 1484
#
#      simple_address_x                                              Match  \
# 0                4859  [(4859 hawthorne high, 100.0, 4859-hawthorne-h...
# 1               14901  [(14901 lawndale high, 100.0, 14901-lawndale-h...
# 2                4118  [(4118 leuzinger high, 100.0, 4118-leuzinger-h...
# 3                4951  [(4951 r k lloyde high, 100.0, 4951-r-k-lloyde...
# 4                 461                                                 []
# ...               ...                                                ...
# 1480             1253  [(1253 cathedral high school, 100.0, 1253-cath...
# 1481             6361  [(6325 the episcopal school of los angeles, 89...
# 1482             9650  [(9650 northpoint school, 100.0, 9650-northpoi...
# 1483                                                                  []
# 1484                                                                  []
#
#       rowid  ... state         zip  \
# 0       306  ...    CA  90250-4204
# 1       307  ...    CA  90260-1251
# 2       308  ...    CA  90260-1601
# 3       310  ...    CA  90260-1251
# 4         0  ...   NaN         NaN
# ...     ...  ...   ...         ...
# 1480    862  ...    CA  90012-1453
# 1481    825  ...    CA  90038-1694
# 1482    843  ...    CA  91325-2003
# 1483      0  ...   NaN         NaN
# 1484      0  ...   NaN         NaN
#
#                                         original_name_y  \
# 0          Hawthorne High (Centinela Valley Union High)
# 1           Lawndale High (Centinela Valley Union High)
# 2          Leuzinger High (Centinela Valley Union High)
# 3       R. K. Lloyde High (Centinela Valley Union High)
# 4                                                   NaN
# ...                                                 ...
# 1480  Cathedral High School (Independent Charter Sch...
# 1481  The Episcopal School of Los Angeles (Independe...
# 1482  Northpoint School (Independent Charter Schools...
# 1483                                                NaN
# 1484                                                NaN
#
#                                     name_y simple_address_y  \
# 0                          Hawthorne High              4859
# 1                           Lawndale High             14901
# 2                          Leuzinger High              4118
# 3                       R. K. Lloyde High              4951
# 4                                      NaN              NaN
# ...                                    ...              ...
# 1480                Cathedral High School              1253
# 1481  The Episcopal School of Los Angeles              6325
# 1482                    Northpoint School              9650
# 1483                                   NaN              NaN
# 1484                                   NaN              NaN
#
#                                     simple_name             district  \
# 0                          4859-hawthorne-high-                  NaN
# 1                          14901-lawndale-high-                  NaN
# 2                          4118-leuzinger-high-                  NaN
# 3                         4951-r-k-lloyde-high-                  NaN
# 4                                           NaN              Charter
# ...                                         ...                  ...
# 1480                1253-cathedral-high-school-                  NaN
# 1481  6325-the-episcopal-school-of-los-angeles-                  NaN
# 1482                    9650-northpoint-school-                  NaN
# 1483                                        NaN  Santa Monica-Malibu
# 1484                                        NaN        Whittier UHSD
#
#      participating  duped               score
# 0             True  False               100.0
# 1             True  False               100.0
# 2             True  False               100.0
# 3             True  False               100.0
# 4             True  False                 NaN
# ...            ...    ...                 ...
# 1480          True  False               100.0
# 1481          True  False   89.47368421052632
# 1482          True  False               100.0
# 1483          True   True                 NaN
# 1484          True   True                 NaN
#
# [1485 rows x 24 columns]

# %% [markdown]
# ## 5.0 Final Column Selection
# Here we select the final data columns for our outputs, with `_x` suffixes representing the original Metro dataset and `_y` suffixes representing the California schools dataset.
#
# - "district_x"
# - "district_y"
# - "original_name_x"
# - "original_name_y"
# - "status"
# - 'closed_date'
# - "full_name"
# - "full_name_some"
# - "participating"
# - "address_x"
# - "address_y"
# - "city_x"
# - "city_y"
# - 'address_y'
# - 'city_y'
# - "score"
# - "duped"
# - 'phone'
# - 'email'
# - 'website'
# - 'latitude'
# - 'longitude'
# - 'last_update'

# %%
# final_columns = {
#     "full_name":"school_name",
#     "full_name_some":"school_name_with_some_districts_attached"
# }

# final_df = merged_df[["oid","district_x","district_y","original_name_x","original_name_y","status",'closed_date',
#        "full_name","full_name_some","participating","address_x","address_y","city_x","city_y","score","duped",'phone', 'email',
#        'website', 'latitude', 'longitude', 'last_update']]
final_df = merged_df

# final_df["address"] = final_df["address_x"] 


# final_df.rename(inplace=True)
# final_df.reset_index(inplace=True)
# final_df.rename(inplace=True, columns=final_columns)
final_df.reset_index(inplace=True)
# final_df.index.names = ['id']
final_df.index.names = ['id']

final_df
# Out:
#       index           district_x                                     name_x  \
# id
# 0         0     Centinela Valley                       4859-hawthorne-high-
# 1         1     Centinela Valley                       14901-lawndale-high-
# 2         2     Centinela Valley                       4118-leuzinger-high-
# 3         3     Centinela Valley                      4951-r-k-lloyde-high-
# 4         4              Charter                                        NaN
# ...     ...                  ...                                        ...
# 1480   1480              Private                1253-cathedral-high-school-
# 1481   1481              Private  6325-the-episcopal-school-of-los-angeles-
# 1482   1482              Private                    9650-northpoint-school-
# 1483   1483  Santa Monica-Malibu                                        NaN
# 1484   1484        Whittier UHSD                                        NaN
#
#                          address       city_x           phone  \
# id
# 0     4859 West El Segundo Blvd.    Hawthorne  (310) 263-4400
# 1      14901 S. Inglewood Avenue     Lawndale  (310) 263-3100
# 2       4118 West Rosecrans Ave.     Lawndale  (310) 263-2200
# 3               4951 Marine Ave.     Lawndale  (310) 263-3264
# 4      461 9th Street, San Pedro    San Pedro  (310) 221-0430
# ...                          ...          ...             ...
# 1480           1253 Bishops Road  Los Angeles  (323) 441-3113
# 1481     6361 Santa Monica Blvd.  Los Angeles  (323) 284-7266
# 1482            9650 Zelzah Ave.   Northridge  (818) 739-5231
# 1483
# 1484
#
#                     email                                    original_name_x  \
# id
# 0                 No Data                                     Hawthorne High
# 1                 No Data                                      Lawndale High
# 2                 No Data                                     Leuzinger High
# 3                 No Data                                  R. K. Lloyde High
# 4                          Alliance Alice M. Baxter College-Ready High Sc...
# ...                   ...                                                ...
# 1480    brjohnm@chsla.org                              Cathedral High School
# 1481  registrar@es-la.com                    Episcopal School of Los Angeles
# 1482                                                       Northpoint School
# 1483
# 1484
#
#      simple_address_x                                              Match  ...  \
# id                                                                        ...
# 0                4859  [(4859 hawthorne high, 100.0, 4859-hawthorne-h...  ...
# 1               14901  [(14901 lawndale high, 100.0, 14901-lawndale-h...  ...
# 2                4118  [(4118 leuzinger high, 100.0, 4118-leuzinger-h...  ...
# 3                4951  [(4951 r k lloyde high, 100.0, 4951-r-k-lloyde...  ...
# 4                 461                                                 []  ...
# ...               ...                                                ...  ...
# 1480             1253  [(1253 cathedral high school, 100.0, 1253-cath...  ...
# 1481             6361  [(6325 the episcopal school of los angeles, 89...  ...
# 1482             9650  [(9650 northpoint school, 100.0, 9650-northpoi...  ...
# 1483                                                                  []  ...
# 1484                                                                  []  ...
#
#       state         zip                                    original_name_y  \
# id
# 0        CA  90250-4204       Hawthorne High (Centinela Valley Union High)
# 1        CA  90260-1251        Lawndale High (Centinela Valley Union High)
# 2        CA  90260-1601       Leuzinger High (Centinela Valley Union High)
# 3        CA  90260-1251    R. K. Lloyde High (Centinela Valley Union High)
# 4       NaN         NaN                                                NaN
# ...     ...         ...                                                ...
# 1480     CA  90012-1453  Cathedral High School (Independent Charter Sch...
# 1481     CA  90038-1694  The Episcopal School of Los Angeles (Independe...
# 1482     CA  91325-2003  Northpoint School (Independent Charter Schools...
# 1483    NaN         NaN                                                NaN
# 1484    NaN         NaN                                                NaN
#
#                                     name_y simple_address_y  \
# id
# 0                          Hawthorne High              4859
# 1                           Lawndale High             14901
# 2                          Leuzinger High              4118
# 3                       R. K. Lloyde High              4951
# 4                                      NaN              NaN
# ...                                    ...              ...
# 1480                Cathedral High School              1253
# 1481  The Episcopal School of Los Angeles              6325
# 1482                    Northpoint School              9650
# 1483                                   NaN              NaN
# 1484                                   NaN              NaN
#
#                                     simple_name             district  \
# id
# 0                          4859-hawthorne-high-                  NaN
# 1                          14901-lawndale-high-                  NaN
# 2                          4118-leuzinger-high-                  NaN
# 3                         4951-r-k-lloyde-high-                  NaN
# 4                                           NaN              Charter
# ...                                         ...                  ...
# 1480                1253-cathedral-high-school-                  NaN
# 1481  6325-the-episcopal-school-of-los-angeles-                  NaN
# 1482                    9650-northpoint-school-                  NaN
# 1483                                        NaN  Santa Monica-Malibu
# 1484                                        NaN        Whittier UHSD
#
#      participating  duped               score
# id
# 0             True  False               100.0
# 1             True  False               100.0
# 2             True  False               100.0
# 3             True  False               100.0
# 4             True  False                 NaN
# ...            ...    ...                 ...
# 1480          True  False               100.0
# 1481          True  False   89.47368421052632
# 1482          True  False               100.0
# 1483          True   True                 NaN
# 1484          True   True                 NaN
#
# [1485 rows x 25 columns]

# %%
final_df = final_df.drop(columns=['city_x','simple_address_x','email','simple_address_y','state','zip','name_y','city_y'])

final_df.columns
# Out:
# Index(['index', 'district_x', 'name_x', 'address', 'phone', 'original_name_x',
#        'Match', 'rowid', 'school', 'district_y', 'street', 'original_name_y',
#        'simple_name', 'district', 'participating', 'duped', 'score'],
#       dtype='object')

# %% [markdown]
# ## 5.0 Final Output
# Using today's date and the csv file extension we will output the file to the data directory.
#
# We also split the data using `to_json` in pandas, more info here:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_json.html

# %%
today = str(datetime.now().strftime("%Y-%m-%d"))
outfile_extension = ".csv"
output_file_name = "../data/tap_data_merged_with_metro_california_qc_data_"+today+outfile_extension

final_df.to_csv(output_file_name)

#create JSON file oriented by records
output_json = "../src/data/schools.json"
json_file = final_df.to_json(orient='records',index=True) 
with open(output_json, 'w') as f:
    f.write(json_file)

# %%
# Done!
